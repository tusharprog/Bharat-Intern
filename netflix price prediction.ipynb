# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("NFLX.csv")

# %%
df.head()
# Out:
#          Date        Open        High         Low       Close   Adj Close  \
# 0  2018-02-05  262.000000  267.899994  250.029999  254.259995  254.259995
# 1  2018-02-06  247.699997  266.700012  245.000000  265.720001  265.720001
# 2  2018-02-07  266.579987  272.450012  264.329987  264.559998  264.559998
# 3  2018-02-08  267.079987  267.619995  250.000000  250.100006  250.100006
# 4  2018-02-09  253.850006  255.800003  236.110001  249.470001  249.470001
#
#      Volume
# 0  11896100
# 1  12595800
# 2   8981500
# 3   9306700
# 4  16906900

# %%
df['Change'] = round(- 100 +(df["Close"] * 100 / df["Open"]),2)

# %%
is_same = df["Close"] == df["Adj Close"]
is_same.value_counts()
# Out:
# True    1009
# dtype: int64

# %% [markdown]
# On enlève la colonne "Adj Close" car on a les mêmes valeurs sur "Close".

# %%
df = df.drop("Adj Close", axis = 1)

# %%
df1 = df.copy()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1009 entries, 0 to 1008
# Data columns (total 7 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Date    1009 non-null   object
#  1   Open    1009 non-null   float64
#  2   High    1009 non-null   float64
#  3   Low     1009 non-null   float64
#  4   Close   1009 non-null   float64
#  5   Volume  1009 non-null   int64
#  6   Change  1009 non-null   float64
# dtypes: float64(5), int64(1), object(1)
# memory usage: 55.3+ KB

# %%
import matplotlib.pyplot as plt

# %%
df.plot(x = "Date", y = ["Open","Close"], kind = "line")
plt.ylabel("Euros")
plt.show()

# %%
df.plot(x = "Date", y = "Change", kind = "line")
plt.show()

# %% [markdown]
# On va essayer les regrouper par Mois et Année pour voir mieux dedans.

# %%
df["Date"] = pd.to_datetime(df["Date"])

# %%
per_month = df.set_index("Date").groupby(pd.Grouper(freq = "M")).mean()
per_month = per_month.reset_index()

# %%
import seaborn as sns

# %%
fig, ax1 = plt.subplots(figsize=(12,6))

sns.lineplot(data = per_month["Change"] , marker='o', sort = False, ax=ax1)
plt.xticks(rotation = 80)
ax2 = ax1.twinx()

sns.barplot(data = per_month, x = per_month['Date'].dt.date, y = 'Volume', alpha = 0.5, ax = ax2)

plt.show()

# %% [markdown]
# Sur des plus grands volumes, le change baisse et augmente sur des plus petits volumes.

# %%
pd.melt(per_month[["Close","Open","Date"]],["Date"])
# Out:
#          Date variable       value
# 0  2018-02-28    Close  272.054705
# 1  2018-03-31    Close  312.228097
# 2  2018-04-30    Close  307.466192
# 3  2018-05-31    Close  331.536819
# 4  2018-06-30    Close  384.133336
# ..        ...      ...         ...
# 93 2021-10-31     Open  639.220474
# 94 2021-11-30     Open  671.363334
# 95 2021-12-31     Open  611.568640
# 96 2022-01-31     Open  492.055000
# 97 2022-02-28     Open  427.489998
#
# [98 rows x 3 columns]

# %%
sns.lineplot(x = "Date", y = "value",hue = "variable", data = pd.melt(per_month[["Close","Open","Date"]],["Date"]))
plt.xticks(rotation = 80)
plt.show()

# %% [markdown]
# Passons à la régression :

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %%
df1 = df1.drop("Date",axis = 1)

# %%
X = df1.drop("Close",axis = 1)
y = df1["Close"]

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size = .2)

# %%
lr = LinearRegression()

# %%
lr.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred = lr.predict(X_test)
y_pred
# Out:
# array([291.2012952 , 414.40350811, 316.39979277, 489.92188849,
#        328.14461583, 512.80023493, 352.51317665, 550.76227072,
#        507.00361376, 273.11110792, 472.90829056, 285.79999086,
#        370.66971642, 330.7985089 , 357.07007503, 516.1284558 ,
#        351.19918083, 380.57610751, 377.68043067, 490.00048885,
#        341.58293698, 542.20380965, 291.14493324, 263.8722558 ,
#        487.95294753, 517.53072969, 293.87225602, 286.08493995,
#        517.08916669, 376.80881695, 289.31789383, 294.87725849,
#        552.7376515 , 489.53690812, 310.08295335, 515.10349779,
#        512.33817138, 316.44213266, 431.15686509, 288.14479068,
#        374.09917966, 343.45864734, 521.6393615 , 453.82601827,
#        593.30973375, 382.6985866 , 492.46567922, 486.95935979,
#        597.92824766, 530.79161752, 279.21166861, 361.79419052,
#        487.00847229, 321.29230118, 536.75217851, 350.02454019,
#        468.7938825 , 297.38216842, 482.91203083, 364.82588728,
#        251.46386366, 380.73040175, 289.67452493, 547.31309441,
#        299.94622501, 527.91237122, 276.17593454, 337.24888365,
#        296.94198638, 348.42196994, 515.34783491, 314.23560267,
#        312.95244614, 550.60865332, 609.27905318, 592.80023256,
#        505.84573845, 405.02309361, 354.92623794, 512.60340011,
#        321.34211371, 605.06332673, 303.32109524, 669.32143509,
#        533.85209262, 270.59363145, 415.27671133, 511.24455824,
#        499.10274147, 319.63817539, 360.67409635, 312.08369469,
#        510.28993257, 324.24659469, 579.6908968 , 421.47063565,
#        271.0828851 , 288.80601858, 396.65225872, 437.80949442,
#        500.06970042, 317.11220002, 307.77534019, 484.0928386 ,
#        507.03524626, 512.2550109 , 486.03386733, 413.47132327,
#        354.37621914, 635.38487252, 605.48769464, 348.99894926,
#        648.89167993, 511.43564399, 432.910495  , 360.11110235,
#        627.35009211, 546.08318532, 427.06097596, 348.74219018,
#        258.96271023, 539.77529014, 374.88898324, 505.80293481,
#        273.65417765, 473.67453961, 271.46813631, 645.50232082,
#        270.4349129 , 497.70096484, 451.52658305, 356.73180366,
#        374.84265908, 416.98882646, 464.17112836, 419.838736  ,
#        322.53348981, 348.30365497, 317.30382217, 360.04234262,
#        315.32296054, 550.10872816, 356.63273674, 452.61119712,
#        501.89659305, 356.09268301, 354.69619727, 291.92531583,
#        580.76033636, 527.4462388 , 414.20395347, 551.25283842,
#        350.21435563, 549.61685019, 504.18835036, 512.65923184,
#        289.06049792, 352.09195031, 337.57542434, 283.10798012,
#        488.78699575, 354.89561712, 422.34749554, 484.22384268,
#        353.86972953, 297.67032365, 324.56861574, 344.5795122 ,
#        296.14456048, 447.22407128, 293.52286659, 300.88423736,
#        339.19561655, 501.7658664 , 548.94044691, 353.27468439,
#        580.18583167, 542.09505697, 348.23332489, 341.80224846,
#        539.46217952, 316.16975883, 378.45885075, 418.59756317,
#        502.94307837, 369.44238864, 537.04382054, 541.48124807,
#        516.79264107, 444.24563487, 435.80452251, 489.13385458,
#        507.2944531 , 379.52114303, 336.42538034, 299.05602874,
#        488.1579069 , 563.91743443, 364.80076856, 351.66288891,
#        577.29208164, 538.52408448])

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error, mean_absolute_percentage_error,r2_score

# %%
Validation = [["MSE:",  mean_squared_error(y_test,y_pred)], ["RMAE:",  np.sqrt(mean_absolute_error(y_test,y_pred))],
              ["MAE:", mean_absolute_error(y_test,y_pred)], ["r2:",  r2_score(y_test,y_pred)]]

# %%
for name,val in Validation :
    val = val
    print(name, round(val,3))
# Out:
# MSE: 4.622
# RMAE: 1.223
# MAE: 1.496
# r2: 1.0

# %%
def style():
    plt.figure(facecolor = "black",figsize = (15,10))
    ax = plt.axes()
    ax.tick_params(axis = "x", colors = "white")
    ax.tick_params(axis = "y", colors = "white")
    
    ax.spines['left'].set_color('white')
    ax.spines['bottom'].set_color('white')
    ax.set_facecolor("black")

# %%
style()

plt.scatter(y_pred, y_test, color='red', marker='o')
plt.scatter(y_test, y_test, color='blue')
plt.plot(y_test, y_test, color='lime')
